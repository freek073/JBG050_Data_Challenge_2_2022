# %% [markdown]
# # Approach 1 - use street data
#
# postcode files can be downloaded here: https://www.doogal.co.uk/PostcodeDownloads.php .
#
# Look at England, Wales, NI

# %% [markdown]
# ## Load libraries and data

# %%
import pandas as pd
import os
import tqdm as tq
import string
import statistics as stats
import re
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# Use the parsing function defined in "Data aggregation"

# %%
# To make a dataframe for street for one police force only (pf name must correspond to the one in file name)

def extract_street_for_force(pf: str):
    directory = "/Users/hannabroszczak/Desktop/uni/DataChallenge2/Jan_2012_Oct_2021" # Change directory
    df_street = pd.DataFrame()

    folders = [folder for folder in os.listdir(directory) if not str(folder).strip("'b").startswith('.')]

    for folder in folders:
        files_street = []

        # Here you can change the date range
        if int(folder[:4]) > 2014:
            # generate the path to folder
            folder_direc = os.fsencode(directory + '/'+ str(folder))
        
            # add each file name to the appropriate list
            for file in os.listdir(folder_direc):
                file = str(file).strip("'b")
                # check if the file name contains the appropriate district name and 'street'
                if (bool(re.search(str(pf), file))) & (bool(re.search('street', file))):
                        files_street.append(file)
                
            # Clean dataframe
            for file in files_street:
                # Create dataframe from the current file
                current_data_street = pd.read_csv(directory + '/' + str(folder).strip("'b") + '/' + str(file)) 
                # Drop the attributes considered irrelevant
                current_data_street.drop(['Reported by','Location', 'Context', 'LSOA name'], axis=1, inplace=True)
                current_data_street.dropna(subset=['LSOA code'], inplace=True)
                current_data_street.dropna(subset=['Crime type'], inplace=True)
                df_street = df_street.append(current_data_street)
    return df_street

def extract_sas_for_force(pf):
    directory = "/Users/hannabroszczak/Desktop/uni/DataChallenge2/Jan_2012_Oct_2021" # Change directory
    df_sas = pd.DataFrame()

    folders = [folder for folder in os.listdir(directory) if not str(folder).strip("'b").startswith('.')]
    
    for folder in folders:
        files_sas = []

        # Here you can change the date range
        if int(folder[:4]) > 2014:
            # generate the path to folder
            folder_direc = os.fsencode(directory + '/'+ str(folder))
        
            # add each file name to the appropriate list
            for file in os.listdir(folder_direc):
                file = str(file).strip("'b")
                # check if the file name contains the appropriate district name and 'street'
                if (bool(re.search(str(pf), file))) & (bool(re.search('stop-and-search', file))):
                        files_sas.append(file)
                
            # Clean dataframe for stop-and-search
            for file in files_sas:
                # Create dataframe from the current file
                current_data_sas = pd.read_csv(directory + '/' + str(folder).strip("'b") + '/' + str(file))  
                # drop the attributes considered irrelevant
                current_data_sas.drop(['Policing operation', 'Gender', 'Object of search', \
                                      'Outcome linked to object of search', 'Removal of more than just outer clothing',
                                      'Self-defined ethnicity', 'Officer-defined ethnicity'], axis=1, inplace=True)
                # drop rows which do not have the "Type" specified
                current_data_sas.dropna(subset=['Type'], inplace=True)
                current_data_sas.dropna(subset=['Longitude'], inplace=True)
                current_data_sas.dropna(subset=['Latitude'], inplace=True)
                df_sas = df_sas.append(current_data_sas)
    return  df_sas

# %%
# extract all street data for one police force
df_str_dict = extract_street_for_force("essex")

# %%
# append street data from some other police forces to generate a more 
# extensive dataset-dictionary
df_str_dict = df_str_dict.append(extract_street_for_force('cheshire'))
df_str_dict = df_str_dict.append(extract_street_for_force('essex'))
df_str_dict = df_str_dict.append(extract_street_for_force('norfolk'))

# %%
# add some more data
df_str_dict = df_str_dict.append(extract_street_for_force('avon'))
df_str_dict = df_str_dict.append(extract_street_for_force('london'))
df_str_dict = df_str_dict.append(extract_street_for_force('devon'))
# df_str_dict = df_str_dict.append(extract_street_for_force('cleveland'))
# df_str_dict = df_str_dict.append(extract_street_for_force('durham'))
# df_str_dict = df_str_dict.append(extract_street_for_force('wales'))
# df_str_dict = df_str_dict.append(extract_street_for_force('thames'))

# %%
# extract the sas data for one police force
df_sas_btp = extract_sas_for_force("essex")

# %% [markdown]
# ## Creating a "dictionary" (data frame) for recreating LSOA is sas

# %%
# create a new df with unique LSOA codes and some corresponding
# Longitude and Latitude values
# df_lsoa = df_str_dict.copy().drop_duplicates(subset='LSOA code')
df_lsoa = df_str_dict[['LSOA code','Longitude','Latitude']].groupby('LSOA code').mean()

# %%
# round Longitude and Latitude values to 5 decimal places (initially 6 given)
df_lsoa['Longitude'] = round(df_lsoa['Longitude'], 3)
df_lsoa['Latitude'] = round(df_lsoa['Latitude'], 3)

# %%
df_lsoa = df_lsoa.reset_index()

# %%
df_lsoa
# Out:
#       LSOA code  Longitude  Latitude
# 0     E01000001     -0.097    51.518
# 1     E01000002     -0.092    51.519
# 2     E01000003     -0.095    51.521
# 3     E01000005     -0.076    51.514
# 4     E01000006      0.087    51.540
# ...         ...        ...       ...
# 8064  W01001937     -4.052    52.503
# 8065  W01001939     -3.180    51.483
# 8066  W01001942     -3.168    51.461
# 8067  W01001943     -3.165    51.468
# 8068  W01001952     -3.176    51.472
#
# [8069 rows x 3 columns]

# %% [markdown]
# ## Recreate LSOA codes in df_sas

# %%
# round Longitude and Latitude values in sas 
# to 5 decimal places (initially 6 given)
df_sas_btp['Longitude'] = round(df_sas_btp['Longitude'], 3)
df_sas_btp['Latitude'] = round(df_sas_btp['Latitude'], 3)

# %%
# merge the 2 dataframes based on longitude and latitude - results in
# adding LSOA code to the sas df
df_sas_lsoa =pd.merge( df_sas_btp, df_lsoa, on=['Latitude', 'Longitude'], how='left')

# %%
df_sas_lsoa[df_sas_lsoa['LSOA code'].notna()]
# Out:
#                             Type                       Date  \
# 6                  Person search  2020-01-01T01:01:00+00:00
# 19                 Person search  2020-01-01T06:01:00+00:00
# 203                Person search  2020-01-04T23:01:00+00:00
# 204                Person search  2020-01-04T23:01:00+00:00
# 207                Person search  2020-01-04T23:01:00+00:00
# ...                          ...                        ...
# 64407  Person and Vehicle search  2018-12-16T02:01:00+00:00
# 64408              Person search  2018-12-16T02:01:00+00:00
# 64453             Vehicle search  2018-12-17T21:01:00+00:00
# 64509  Person and Vehicle search  2018-12-20T01:01:00+00:00
# 64557              Person search  2018-12-21T19:01:00+00:00
#
#        Part of a policing operation  Latitude  Longitude Age range  \
# 6                             False    51.614      0.320     25-34
# 19                            False    51.881      0.912     18-24
# 203                           False    51.886      0.938   over 34
# 204                           False    51.886      0.938     25-34
# 207                           False    51.886      0.938   over 34
# ...                             ...       ...        ...       ...
# 64407                         False    51.603      0.528     25-34
# 64408                         False    51.603      0.528     25-34
# 64453                         False    51.751      0.071       NaN
# 64509                          True    51.526      0.596   over 34
# 64557                         False    51.889      0.899   over 34
#
#                                              Legislation  \
# 6                  Misuse of Drugs Act 1971 (section 23)
# 19     Police and Criminal Evidence Act 1984 (section 1)
# 203                Misuse of Drugs Act 1971 (section 23)
# 204                Misuse of Drugs Act 1971 (section 23)
# 207                Misuse of Drugs Act 1971 (section 23)
# ...                                                  ...
# 64407              Misuse of Drugs Act 1971 (section 23)
# 64408              Misuse of Drugs Act 1971 (section 23)
# 64453  Police and Criminal Evidence Act 1984 (section 1)
# 64509              Misuse of Drugs Act 1971 (section 23)
# 64557              Misuse of Drugs Act 1971 (section 23)
#
#                             Outcome  LSOA code
# 6          Khat or Cannabis warning  E01021435
# 19     A no further action disposal  E01021688
# 203    A no further action disposal  E01021700
# 204    A no further action disposal  E01021700
# 207    A no further action disposal  E01021700
# ...                             ...        ...
# 64407      Khat or Cannabis warning  E01021343
# 64408  A no further action disposal  E01021343
# 64453  A no further action disposal  E01021865
# 64509  A no further action disposal  E01021493
# 64557  A no further action disposal  E01021649
#
# [1614 rows x 9 columns]

# %%
# add the column with Month (format yyyy-mm) to sas df
df_sas_lsoa['Month'] = df_sas_lsoa['Date'].apply(lambda x: x[:7])

# %%
# group sas df by Month and the LSOA code generated based on street df
df_sas_lsoa.groupby(['Month', 'LSOA code']).count()['Type'].to_frame()
# Out:
#                    Type
# Month   LSOA code
# 2015-04 E01021577     2
#         E01021664     1
#         E01022079     5
#         E01022081     5
#         E01033140     2
# ...                 ...
# 2021-10 E01033614     2
#         E01033719    13
#         E01033722     9
#         E01033723     2
#         W01000574     1
#
# [25726 rows x 1 columns]

# %% [markdown]
# # Approach 2 - use external file

# %%
df_sas_btp['Longitude'] = round(df_sas_btp['Longitude'], 3)
df_sas_btp['Latitude'] = round(df_sas_btp['Latitude'], 3)

# %%
# read the csv with LSOA codes and long/lat values
postcodes = pd.read_csv('Wales postcodes.csv')
postcodes = postcodes.append(pd.read_csv('BT postcodes.csv'))

# %%
postcodes = postcodes.append(pd.read_csv('England postcodes.csv'))
# Out:
# /Users/hannabroszczak/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (18,29,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
postcodes = postcodes[['LSOA Code', 'Latitude', 'Longitude']]
# Out:
#          LSOA Code   Latitude  Longitude
# 0        W01001767  51.469744  -3.187692
# 1        W01001767  51.469744  -3.187692
# 2        W01001939  51.477907  -3.180704
# 3        W01001767  51.469744  -3.187692
# 4        W01001939  51.479690  -3.182190
# ...            ...        ...        ...
# 2230312  E01013406  53.978208  -1.065358
# 2230313  E01013406  53.978208  -1.065358
#     Part of a policing operation  Latitude  Longitude Age range  \
# 0                          False     51.84       0.78     10-17
# 1                          False     51.84       0.78     10-17
# 2                          False     51.84       0.78     10-17
# 3                          False     51.84       0.78       NaN
# 4                          False     51.54       0.69   over 34
# 5                          False     51.84       0.78     18-24
# 6                          False     51.61       0.32     25-34
# 7                          False     51.84       0.78     10-17
# 8                          False     51.84       0.78     18-24
# 9                          False     51.56       0.42       NaN
# 10                         False     51.73       0.47       NaN
# 11                         False     51.79       1.16     10-17
# 12                         False     51.79       1.15     18-24
# 13                         False     51.73       0.47     18-24
# 14                         False     51.73       0.47     18-24
# 15                         False     51.54       0.71     18-24
# 16                         False     51.54       0.71     18-24
# 17                         False     51.56       0.56     18-24
# 18                         False     51.74       0.06     25-34
# 19                         False     51.88       0.91     18-24
# 20                         False     51.74       0.63   over 34
# 21                         False     51.74       0.63     25-34
# 22                         False     51.65       0.75   over 34
# 23                         False     51.89       0.83   over 34
# 24                         False     51.89       0.88     18-24
# 25                         False     51.74       0.50     18-24
# 26                         False     51.55       0.70   over 34
# 27                         False     51.54       0.73   over 34
# 28                         False     51.55       0.68   over 34
# 29                         False     51.63       0.30     18-24
# 30                         False     51.63       0.30     18-24
# 31                         False     51.88       0.83     10-17
# 32                         False     51.72       0.45     25-34
# 33                         False     51.72       0.45     25-34
# 34                         False     51.73       0.68     18-24
# 35                         False     51.73       0.68     18-24
# 36                         False     51.89       0.89     10-17
# 37                         False     51.69       0.01     25-34
# 38                         False     51.77       0.05     18-24
# 39                         False     51.76       0.08     18-24
# 40                         False     51.72       0.49   over 34
# 41                         False     51.55       0.65   over 34
# 42                         False     51.64       0.62     18-24
# 43                         False     51.75       0.09     10-17
# 44                         False     51.77       0.09     10-17
# 45                         False     51.75       0.09       NaN
# 46                         False     51.57       0.43     18-24
# 47                         False     51.77       0.09     10-17
# 48                         False     51.77       0.09       NaN
# 49                         False     51.75       0.09     18-24
#
#                                           Legislation  \
# 0               Misuse of Drugs Act 1971 (section 23)
# 1               Misuse of Drugs Act 1971 (section 23)
# 2               Misuse of Drugs Act 1971 (section 23)
# 3               Misuse of Drugs Act 1971 (section 23)
# 4   Police and Criminal Evidence Act 1984 (section 1)
# 5               Misuse of Drugs Act 1971 (section 23)
# 6               Misuse of Drugs Act 1971 (section 23)
# 7               Misuse of Drugs Act 1971 (section 23)
# 8               Misuse of Drugs Act 1971 (section 23)
# 9   Police and Criminal Evidence Act 1984 (section 1)
# 10              Misuse of Drugs Act 1971 (section 23)
# 11              Misuse of Drugs Act 1971 (section 23)
# 12              Misuse of Drugs Act 1971 (section 23)
# 13  Police and Criminal Evidence Act 1984 (section 1)
# 14  Police and Criminal Evidence Act 1984 (section 1)
# 15  Police and Criminal Evidence Act 1984 (section 1)
# 16  Police and Criminal Evidence Act 1984 (section 1)
# 17  Police and Criminal Evidence Act 1984 (section 1)
# 18              Misuse of Drugs Act 1971 (section 23)
# 19  Police and Criminal Evidence Act 1984 (section 1)
# 20  Police and Criminal Evidence Act 1984 (section 1)
# 21  Police and Criminal Evidence Act 1984 (section 1)
# 22  Police and Criminal Evidence Act 1984 (section 1)
# 23  Police and Criminal Evidence Act 1984 (section 1)
# 24  Police and Criminal Evidence Act 1984 (section 1)
# 25              Misuse of Drugs Act 1971 (section 23)
# 26              Misuse of Drugs Act 1971 (section 23)
# 27              Misuse of Drugs Act 1971 (section 23)
# 28              Misuse of Drugs Act 1971 (section 23)
# 29              Misuse of Drugs Act 1971 (section 23)
# 30              Misuse of Drugs Act 1971 (section 23)
# 31              Misuse of Drugs Act 1971 (section 23)
# 32              Misuse of Drugs Act 1971 (section 23)
# 33              Misuse of Drugs Act 1971 (section 23)
# 34              Misuse of Drugs Act 1971 (section 23)
# 35              Misuse of Drugs Act 1971 (section 23)
# 36              Misuse of Drugs Act 1971 (section 23)
# 37              Misuse of Drugs Act 1971 (section 23)
# 38  Police and Criminal Evidence Act 1984 (section 1)
# 39              Misuse of Drugs Act 1971 (section 23)
# 40  Police and Criminal Evidence Act 1984 (section 1)
# 41              Misuse of Drugs Act 1971 (section 23)
# 42              Misuse of Drugs Act 1971 (section 23)
# 43              Misuse of Drugs Act 1971 (section 23)
# 44              Misuse of Drugs Act 1971 (section 23)
# 45              Misuse of Drugs Act 1971 (section 23)
# 46              Misuse of Drugs Act 1971 (section 23)
# 47              Misuse of Drugs Act 1971 (section 23)
# 48              Misuse of Drugs Act 1971 (section 23)
# 49              Misuse of Drugs Act 1971 (section 23)
#
#                             Outcome
# 0              Community resolution
# 1              Community resolution
# 2              Community resolution
# 3              Community resolution
# 4                               NaN
# 5          Khat or Cannabis warning
# 6          Khat or Cannabis warning
# 7      A no further action disposal
# 8      A no further action disposal
# 9                            Arrest
# 10     A no further action disposal
# 11     A no further action disposal
# 12     A no further action disposal
# 13     A no further action disposal
# 14     A no further action disposal
# 15     A no further action disposal
# 16     A no further action disposal
# 17     A no further action disposal
# 18     A no further action disposal
# 19     A no further action disposal
# 20     A no further action disposal
# 21     A no further action disposal
# 22                           Arrest
# 23                           Arrest
# 24     A no further action disposal
# 25     A no further action disposal
# 26     A no further action disposal
# 27                           Arrest
# 28                           Arrest
# 29     A no further action disposal
# 30         Khat or Cannabis warning
# 31     A no further action disposal
# 32                           Arrest
# 33                           Arrest
# 34  Caution (simple or conditional)
# 35     A no further action disposal
# 36     A no further action disposal
# 37                           Arrest
# 38     A no further action disposal
# 39     A no further action disposal
# 40     A no further action disposal
# 41     A no further action disposal
# 42         Khat or Cannabis warning
# 43     A no further action disposal
# 44                           Arrest
# 45         Khat or Cannabis warning
# 46                           Arrest
# 47     A no further action disposal
# 48     A no further action disposal
# 49        Summons / charged by post

# %%
postcodes['Latitude'] = round(postcodes['Latitude'], 3)
postcodes['Longitude'] = round(postcodes['Longitude'], 3)

# %%
df_sas_lsoa_postcodes =pd.merge(df_sas_btp, postcodes, on=['Latitude', 'Longitude'], how='inner')

# %%
df_sas_lsoa_postcodes[:50]
# Out:
#                          Type                       Date  \
# 0               Person search  2020-01-01T00:01:00+00:00
# 1               Person search  2020-01-01T00:01:00+00:00
# 2               Person search  2020-01-01T00:01:00+00:00
# 3              Vehicle search  2020-01-01T00:01:00+00:00
# 4               Person search  2020-01-01T01:01:00+00:00
# 5               Person search  2020-01-01T01:01:00+00:00
# 6               Person search  2020-01-01T01:01:00+00:00
# 7               Person search  2020-07-26T00:01:00+00:00
# 8   Person and Vehicle search  2020-07-26T00:01:00+00:00
# 9               Person search  2020-07-26T00:01:00+00:00
# 10  Person and Vehicle search  2018-10-19T22:01:00+00:00
# 11              Person search  2020-02-10T23:01:00+00:00
# 12  Person and Vehicle search  2021-02-24T00:02:00+00:00
# 13              Person search  2020-01-01T01:01:00+00:00
# 14              Person search  2020-01-01T01:01:00+00:00
# 15              Person search  2020-01-01T01:01:00+00:00
# 16              Person search  2020-01-01T01:01:00+00:00
# 17              Person search  2020-01-01T01:01:00+00:00
# 18              Person search  2020-01-01T01:01:00+00:00
# 19              Person search  2020-01-01T01:01:00+00:00
# 20              Person search  2020-01-01T01:01:00+00:00
# 21              Person search  2020-01-01T01:01:00+00:00
# 22              Person search  2020-01-01T01:01:00+00:00
# 23              Person search  2020-01-01T01:01:00+00:00
# 24              Person search  2020-01-01T01:01:00+00:00
# 25              Person search  2020-01-01T01:01:00+00:00
# 26              Person search  2020-01-01T01:01:00+00:00
# 27              Person search  2020-01-01T01:01:00+00:00
# 28              Person search  2020-01-01T01:01:00+00:00
# 29              Person search  2020-01-01T01:01:00+00:00
# 30              Person search  2020-01-01T01:01:00+00:00
# 31              Person search  2020-01-01T01:01:00+00:00
# 32              Person search  2020-01-01T01:01:00+00:00
# 33              Person search  2020-01-01T01:01:00+00:00
# 34              Person search  2020-01-01T01:01:00+00:00
# 35              Person search  2020-01-01T01:01:00+00:00
# 36              Person search  2020-01-01T01:01:00+00:00
# 37              Person search  2020-01-01T01:01:00+00:00
# 38              Person search  2020-01-01T01:01:00+00:00
# 39              Person search  2020-01-01T01:01:00+00:00
# 40              Person search  2020-01-01T01:01:00+00:00
# 41              Person search  2020-01-01T01:01:00+00:00
# 42              Person search  2020-01-01T01:01:00+00:00
# 43              Person search  2020-01-01T01:01:00+00:00
# 44              Person search  2020-01-01T01:01:00+00:00
# 45              Person search  2020-01-01T01:01:00+00:00
# 46              Person search  2020-01-01T01:01:00+00:00
# 47              Person search  2020-01-01T01:01:00+00:00
# 48              Person search  2020-01-01T01:01:00+00:00
# 49              Person search  2020-01-01T01:01:00+00:00
#
#     Part of a policing operation  Latitude  Longitude Age range  \
# 0                          False     51.84       0.78     10-17
# 1                          False     51.84       0.78     10-17
# 2                          False     51.84       0.78     10-17
# 3                          False     51.84       0.78       NaN
# 4                          False     51.84       0.78     18-24
# 5                          False     51.84       0.78     10-17
# 6                          False     51.84       0.78     18-24
# 7                          False     51.84       0.78     25-34
# 8                          False     51.84       0.78     25-34
# 9                          False     51.84       0.78     25-34
# 10                         False     51.84       0.78     25-34
# 11                         False     51.84       0.78     18-24
# 12                         False     51.84       0.78     18-24
# 13                         False     51.54       0.69   over 34
# 14                         False     51.54       0.69   over 34
# 15                         False     51.54       0.69   over 34
# 16                         False     51.54       0.69   over 34
# 17                         False     51.54       0.69   over 34
# 18                         False     51.54       0.69   over 34
# 19                         False     51.54       0.69   over 34
# 20                         False     51.54       0.69   over 34
# 21                         False     51.54       0.69   over 34
# 22                         False     51.54       0.69   over 34
# 23                         False     51.54       0.69   over 34
# 24                         False     51.54       0.69   over 34
# 25                         False     51.54       0.69   over 34
# 26                         False     51.54       0.69   over 34
# 27                         False     51.54       0.69   over 34
# 28                         False     51.54       0.69   over 34
# 29                         False     51.54       0.69   over 34
# 30                         False     51.54       0.69   over 34
# 31                         False     51.54       0.69   over 34
# 32                         False     51.54       0.69   over 34
# 33                         False     51.54       0.69   over 34
# 34                         False     51.54       0.69   over 34
# 35                         False     51.54       0.69   over 34
# 36                         False     51.54       0.69   over 34
# 37                         False     51.54       0.69   over 34
# 38                         False     51.54       0.69   over 34
# 39                         False     51.54       0.69   over 34
# 40                         False     51.54       0.69   over 34
# 41                         False     51.54       0.69   over 34
# 42                         False     51.54       0.69   over 34
# 43                         False     51.54       0.69   over 34
# 44                         False     51.54       0.69   over 34
# 45                         False     51.54       0.69   over 34
# 46                         False     51.54       0.69   over 34
# 47                         False     51.54       0.69   over 34
# 48                         False     51.54       0.69   over 34
# 49                         False     51.54       0.69   over 34
#
#                                           Legislation  \
# 0               Misuse of Drugs Act 1971 (section 23)
# 1               Misuse of Drugs Act 1971 (section 23)
# 2               Misuse of Drugs Act 1971 (section 23)
# 3               Misuse of Drugs Act 1971 (section 23)
# 4               Misuse of Drugs Act 1971 (section 23)
# 5               Misuse of Drugs Act 1971 (section 23)
# 6               Misuse of Drugs Act 1971 (section 23)
# 7               Misuse of Drugs Act 1971 (section 23)
# 8               Misuse of Drugs Act 1971 (section 23)
# 9               Misuse of Drugs Act 1971 (section 23)
# 10              Misuse of Drugs Act 1971 (section 23)
# 11              Misuse of Drugs Act 1971 (section 23)
# 12              Misuse of Drugs Act 1971 (section 23)
# 13  Police and Criminal Evidence Act 1984 (section 1)
# 14  Police and Criminal Evidence Act 1984 (section 1)
# 15  Police and Criminal Evidence Act 1984 (section 1)
# 16  Police and Criminal Evidence Act 1984 (section 1)
# 17  Police and Criminal Evidence Act 1984 (section 1)
# 18  Police and Criminal Evidence Act 1984 (section 1)
# 19  Police and Criminal Evidence Act 1984 (section 1)
# 20  Police and Criminal Evidence Act 1984 (section 1)
# 21  Police and Criminal Evidence Act 1984 (section 1)
# 22  Police and Criminal Evidence Act 1984 (section 1)
# 23  Police and Criminal Evidence Act 1984 (section 1)
